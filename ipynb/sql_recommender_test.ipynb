# %%
cd
# Out:
# /home/jovyan

# %%
from lib.model import recommender

# %%
Foo = recommender.Recommender()

# %%
Foo.update([0, 7, 42])

# %%
Foo.recs
# Out:
# [659,
#  939,
#  714,
#  1636,
#  245,
#  60,
#  39,
#  1033,
#  2033,
#  1181,
#  4818,
#  881,
#  779,
#  946,
#  85,
#  726,
#  1197,
#  3204,
#  814,
#  2218,
#  2046,
#  230,
#  277,
#  153,
#  164,
#  139,
#  333,
#  1051,
#  391,
#  4053,
#  733,
#  755,
#  296,
#  457,
#  287,
#  1040,
#  5247,
#  96,
#  1617,
#  802,
#  2509,
#  5315,
#  22,
#  9003,
#  394,
#  496,
#  2410,
#  1476,
#  5377,
#  5852,
#  7315,
#  5067,
#  2730,
#  1223,
#  2272,
#  967,
#  162,
#  5532,
#  1637,
#  6134,
#  8355,
#  2111,
#  1817,
#  1034,
#  2551,
#  1961,
#  892,
#  3404,
#  2331,
#  2626,
#  721,
#  1935,
#  5175,
#  6049,
#  1609,
#  1641,
#  6167,
#  4350,
#  1279,
#  7688,
#  7848,
#  2115,
#  974,
#  839,
#  3525,
#  3670,
#  811,
#  3029,
#  319,
#  7724,
#  1790,
#  4793,
#  7062,
#  8168,
#  6318,
#  3431,
#  7310,
#  7046,
#  3324,
#  2647,
#  7207,
#  2217,
#  6666,
#  5503,
#  3414,
#  2250,
#  1363,
#  6554,
#  7746,
#  6180,
#  2216,
#  5131,
#  2009,
#  1041,
#  8396,
# ...

# %%
# %run lib/helper/load_search.py

# %%
def search_gname(gs_list):
    '''
    Return of list of gnames from list of gs.
    '''
    return [gname[gs] for gs in gs_list]

# %%
search_gname(Foo.recs)
# Out:
# ['Puerto Rico: Limited Anniversary Edition',
#  'Galaxy Trucker: Anniversary Edition',
#  'Eclipse: Rise of the Ancients',
#  'Vinhos Deluxe Edition',
#  'Viticulture Essential Edition',
#  'Le Havre',
#  'Caylus',
#  'Suburbia Inc',
#  "Sid Meier's Civilization: The Board Game – Wisdom and Warfare",
#  "Sid Meier's Civilization: The Board Game – Fame and Fortune",
#  'Star Wars: Imperial Assault – The Bespin Gambit',
#  'Nippon',
#  'San Juan (second edition)',
#  '51st State: Master Set',
#  'Suburbia',
#  'Kanban: Automotive Revolution',
#  'Saint Petersburg (second edition)',
#  'Star Trek: Fleet Captains – Romulan Empire',
#  'Star Trek: Fleet Captains',
#  'Cuba: El Presidente',
#  'Arkwright',
#  'In the Year of the Dragon',
#  'Glen More',
#  "Sid Meier's Civilization: The Board Game",
#  'Glory to Rome',
#  'Space Alert',
#  'Glass Road',
#  'Stone Age: The Expansion',
#  'London',
#  'The Rivals for Catan: Age of Darkness',
#  'Homesteaders',
# ...

# %%
recommender.bias[0]
# Out:
# 7.1629669563521086

# %%
bar = {1,3,5}

# %%
str(bar)[1:-1]
# Out:
# '1, 3, 5'

# %%
list(bar)
# Out:
# [1, 3, 5]

# %%
len(Foo.sql_tuples)
# Out:
# 3

# %%
test = np.array(tuple([Foo.sql_tuples[0][2][x] for x in Foo.rec_lu]))

# %%
test.shape
# Out:
# (282,)

# %%
import numpy as np

# %%
bar = Foo.sql_tuples[0][2]

# %%
bar[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-d9cb71d7ecb5> in <module>()
# ----> 1 bar[1, 3, 5]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
[*Foo.rec_lu]
# Out:
# [5633,
#  8709,
#  6151,
#  7688,
#  1033,
#  1034,
#  4107,
#  5131,
#  6666,
#  8713,
#  8719,
#  7696,
#  1040,
#  1042,
#  1041,
#  7698,
#  22,
#  8727,
#  9239,
#  3097,
#  6167,
#  1051,
#  8731,
#  8735,
#  8736,
#  8737,
#  9764,
#  6180,
#  7207,
#  39,
#  8233,
#  7724,
#  5168,
#  9781,
#  3127,
#  5175,
#  7736,
#  60,
#  9278,
#  2111,
#  7746,
#  2626,
#  2115,
#  9799,
#  1609,
#  586,
#  2639,
#  4689,
#  1617,
#  9299,
#  85,
#  3670,
#  2647,
#  8797,
#  96,
#  1636,
#  1637,
#  9319,
#  6759,
#  1641,
#  2666,
#  3184,
#  9330,
#  4214,
#  4216,
#  8313,
#  8830,
#  5247,
#  5762,
#  9858,
#  9348,
#  7813,
#  3204,
#  5251,
#  6792,
#  9353,
#  5115,
#  2699,
#  139,
#  7310,
#  7311,
#  4753,
#  9874,
#  659,
#  8339,
#  5781,
#  8851,
#  8855,
#  7315,
#  153,
#  4250,
#  7319,
#  4252,
#  1181,
#  8862,
#  7837,
#  1698,
#  162,
#  7844,
#  164,
#  8355,
#  5282,
#  2216,
#  2217,
#  2218,
#  7850,
#  2730,
#  1197,
#  5805,
#  9894,
#  7848,
#  6318,
# ...
